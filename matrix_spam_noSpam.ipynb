# %%
import numpy as np
import joblib


base_path ="Spam_noSpam.ipynb"
y_test = np.load(base_path + 'y_test.npy')
y_pred = np.load(base_path + 'y_pred.npy')

model = joblib.load(base_path + 'xgboost_spam_model.pkl')

print("Data and model loaded successfully! Ready to evaluate performance.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 6
#       2 import joblib
#       5 base_path ="Spam_noSpam.ipynb"
# ----> 6 y_test = np.load(base_path + 'y_test.npy')
#       7 y_pred = np.load(base_path + 'y_pred.npy')
#       9 model = joblib.load(base_path + 'xgboost_spam_model.pkl')
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\_npyio_impl.py:454, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     452     own_fid = False
#     453 else:
# --> 454     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     455     own_fid = True
#     457 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Spam_noSpam.ipynby_test.npy'
